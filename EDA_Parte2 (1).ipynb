# %% [markdown]
# # Análisis de clientes Haulmer : EDA parte dos
#
# Por : Christian Vergara Retamal - Benjamín Sánchez Aliste
#
# Los siguientes archivos fueron proporcionados por las diversas áreas que interactuan directa e indirectamente con los clientes de Haulmer. El notebook funciona como anezxo de los archivos subidos anteriormente al repositoria de análisis de los datos

# %% [markdown]
# # Aspectos Computacionales
#
# **Librerías utilizadas para el funcionamiento del notebook**
#
# * numpy  versión 1.21.6 : Álgebra lineal y matemáticas
# * pandas versión 1.3.5 : Manejo y análisis de estructuras de datos
# * seaborn versión 0.11.2 : Visualización de gráficos
# * matplotlib 3.2.2 : Gráficos
# * Scikit-learn 1.0.2 : Machine Learning

# %% [markdown]
# # Preparación Ambiente de Trabajo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as stats 
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime
import statsmodels.api as sm
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
plt.style.use('seaborn-whitegrid')
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["figure.dpi"] = 75

# %% [markdown]
# # Archivo **Reporte Comercios s/actividad**

# %%
df_sinact = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Reporte_de_comercios_solo_ocupar_los_NO_.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_sinact.columns
# Out:
# Index(['RUT', 'Nombre Legal', 'Nombre', 'Email', 'Nombre Plan',
#        'Ha recibido pagos? (desde 2022-06-01)'],
#       dtype='object')

# %%
print("Cantidad de registros : ",df_sinact.shape[0])
print("Cantidad de atributos : ",df_sinact.shape[1])
# Out:
# Cantidad de registros :  1190
# Cantidad de atributos :  6

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Reporte Comercios**

# %%
df_sinact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   RUT                                    1190 non-null   object
#  1   Nombre Legal                           1190 non-null   object
#  2   Nombre                                 1190 non-null   object
#  3   Email                                  1190 non-null   object
#  4   Nombre Plan                            1190 non-null   object
#  5   Ha recibido pagos? (desde 2022-06-01)  1190 non-null   object
# dtypes: object(6)
# memory usage: 55.9+ KB

# %%
df_sinact.describe()
# Out:
#                RUT                  Nombre Legal  \
# count         1190                          1190
# unique        1186                          1189
# top     11111111-1  GERSON ARCADIO PULIDO RINCON
# freq             3                             2
#
#                               Nombre                 Email Nombre Plan  \
# count                           1190                  1190        1190
# unique                          1189                  1155           7
# top     GERSON ARCADIO PULIDO RINCON  pymesimple@gmail.com    Plan Tuu
# freq                               2                    10         914
#
#        Ha recibido pagos? (desde 2022-06-01)
# count                                   1190
# unique                                     1
# top                                       NO
# freq                                    1190

# %% [markdown]
# ### Columna RUT

# %%
df_sinact.RUT.value_counts()
# Out:
# 11111111-1    3
# 19469561-6    2
# 25600822-K    2
# 77169667-8    1
# 15756911-2    1
#              ..
# 9045455-2     1
# 77066762-3    1
# 11576701-1    1
# 76049706-1    1
# 10546401-0    1
# Name: RUT, Length: 1186, dtype: int64

# %%
from itertools import cycle
 
def validarRut(rut):
	rut = rut.upper();
	rut = rut.replace("-","")
	rut = rut.replace(".","")
	aux = rut[:-1]
	dv = rut[-1:]
 
	revertido = map(int, reversed(str(aux)))
	factors = cycle(range(2,8))
	s = sum(d * f for d, f in zip(revertido,factors))
	res = (-s)%11
 
	if str(res) == dv:
		return True
	elif dv=="K" and res==10:
		return True
	else:
		return False

# %%
df_sinact["aux_rut"] = df_sinact["RUT"].apply(lambda x : validarRut(x))

# %%
df_sinact.aux_rut.value_counts()
# Out:
# True     1189
# False       1
# Name: aux_rut, dtype: int64

# %%
df_sinact = df_sinact[df_sinact.aux_rut == True]

# %%
df_sinact.drop(columns = ["aux_rut"],inplace=True)

# %%
df_sinact.drop_duplicates(inplace = True)

# %%
df_sinact = df_sinact[df_sinact.RUT != "11111111-1"]

# %%
df_sinact[df_sinact['Email'].str.contains('haulmer')]
# Out:
#             RUT                Nombre Legal                      Nombre  \
# 2    19469561-6                     Alex QA                     Alex QA
# 6    19469561-6               compu Alex SA               compu Alex SA
# 23   76144941-9                    FENG S.A                    FENG S.A
# 916  26802941-9  ROGER EDUARDO GARCIA REYES  ROGER EDUARDO GARCIA REYES
#
#                             Email Nombre Plan  \
# 2         rocio.gomez@haulmer.com    Plan Tuu
# 6    alexander.zuniga@haulmer.com    Plan Tuu
# 23         chiyinfeng@haulmer.com    Plan Tuu
# 916      roger.garcia@haulmer.com    Plan Tuu
#
#     Ha recibido pagos? (desde 2022-06-01)
# 2                                      NO
# 6                                      NO
# 23                                     NO
# 916                                    NO

# %%
values = ["19469561-6", "26802941-9"]
df_sinact = df_sinact[df_sinact.RUT.isin(values) == False]

# %%
df_sinact[df_sinact['Email'].str.contains('haulmer')]
# Out:
#            RUT Nombre Legal    Nombre                   Email Nombre Plan  \
# 23  76144941-9     FENG S.A  FENG S.A  chiyinfeng@haulmer.com    Plan Tuu
#
#    Ha recibido pagos? (desde 2022-06-01)
# 23                                    NO

# %% [markdown]
# ### Nombre Plan

# %%
df_sinact["Nombre Plan"].value_counts()
# Out:
# Plan Tuu                   907
# Plan Tuu [Partner]         118
# Simple                      95
# Simple [Partner]            30
# Plan Tuu+                   24
# OpenRetail Microempresa      5
# Plan Tuu+ [Partner]          4
# Name: Nombre Plan, dtype: int64

# %%
df_sinact.drop(columns = ["Ha recibido pagos? (desde 2022-06-01)"], inplace = True)

# %%
df_sinact.sample(5)
# Out:
#             RUT                                       Nombre Legal  \
# 975  22133104-4                         EDELMIRA TRUJILLO CARRANZA
# 721   9254461-3               VARSOVIA DEL PILAR CABELLO VELASQUEZ
# 93   77466618-4          COMERCIALIZADORA MATAMALA Y PEÑA LIMITADA
# 605  77554771-5  CONFECCIÓN DE BOLSAS DE TELAS DE ALGODÓN NATUR...
# 837   9501800-9                         ERIKA LORETO TORRES AVILES
#
#                                         Nombre                         Email  \
# 975                 EDELMIRA TRUJILLO CARRANZA       accesoriosa@invertic.cl
# 721       VARSOVIA DEL PILAR CABELLO VELASQUEZ  contacto@imprentavarsovia.cl
# 93   COMERCIALIZADORA MATAMALA Y PEÑA LIMITADA       brandon.g1509@gmail.com
# 605                   ISABEL DEL CARMEN ZÚÑIGA       ventas.zi2021@gmail.com
# 837                 ERIKA LORETO TORRES AVILES       kmceroquilpue@gmail.com
#
#             Nombre Plan
# 975  Plan Tuu [Partner]
# 721            Plan Tuu
# 93             Plan Tuu
# 605            Plan Tuu
# 837            Plan Tuu

# %%
categorical_cols = ['Nombre Plan']
lencoder = LabelEncoder()
for col in categorical_cols :
  df_sinact[col] = df_sinact[[col]].apply(lencoder.fit_transform)

# %%
df_sinact.sample(5)
# Out:
#              RUT                                     Nombre Legal  \
# 1121  15147111-0                        ELBA INES LUARDO ANDRADES
# 359   77520215-7  DISTRIBUIDORA LE GUSTA WALTER ESPINOZA E.I.R.L.
# 1077  12128133-3                     MARIA LISBETH HIDALGO CRUCES
# 228   20152359-1                     CAMILA MABEL GUTIERREZ MUNOZ
# 600   76277046-6         INVERSIONES GASTRONOMICAS BAHER LIMITADA
#
#                                         Nombre  \
# 1121                 ELBA INES LUARDO ANDRADES
# 359                            Walter Espinoza
# 1077              MARIA LISBETH HIDALGO CRUCES
# 228               CAMILA MABEL GUTIERREZ MUNOZ
# 600   INVERSIONES GASTRONOMICAS BAHER LIMITADA
#
#                                   Email  Nombre Plan
# 1121               elbaluardo@gmail.com            5
# 359            legusta.dulces@gmail.com            1
# 1077       maryhidalgocrucess@gmail.com            6
# 228           CAMILAMABEL2016@GMAIL.COM            1
# 600   mauricio.henriquez@dondetitor.com            1

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Certificaciones**

# %%
df_certificaciones = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Certificaciones.xlsx")

# %%
df_certificaciones.columns
# Out:
# Index(['Clave', 'Resumen', 'Responsable', 'Estado', 'Creada', 'Actualizada',
#        'RUT Empresa'],
#       dtype='object')

# %%
print("Cantidad de registros : ",df_certificaciones.shape[0])
print("Cantidad de atributos : ",df_certificaciones.shape[1])
# Out:
# Cantidad de registros :  33815
# Cantidad de atributos :  7

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Certificaciones**

# %%
df_certificaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33815 entries, 0 to 33814
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Clave        33815 non-null  object
#  1   Resumen      33815 non-null  object
#  2   Responsable  3303 non-null   object
#  3   Estado       33815 non-null  object
#  4   Creada       33815 non-null  datetime64[ns]
#  5   Actualizada  33815 non-null  datetime64[ns]
#  6   RUT Empresa  27102 non-null  object
# dtypes: datetime64[ns](2), object(5)
# memory usage: 1.8+ MB

# %%
df_certificaciones.describe()
# Out:
#            Clave                            Resumen    Responsable  \
# count      33815                              33815           3303
# unique     33815                              33283             18
# top     CO-34266  : Certificación DTE: LIVEHOST SPA  Jorge Calquín
# freq           1                                 47           1073
# first        NaN                                NaN            NaN
# last         NaN                                NaN            NaN
#
#             Estado               Creada          Actualizada RUT Empresa
# count        33815                33815                33815       27102
# unique          36                33656                26580       14661
# top     Finalizada  2022-06-07 05:49:51  2020-12-30 14:15:25  76353391-3
# freq         16383                    3                   16          89
# first          NaN  2018-03-15 06:15:49  2020-12-30 14:02:17         NaN
# last           NaN  2022-06-13 10:48:17  2022-06-13 11:35:19         NaN

# %%
df_certificaciones.describe(include="object")
# Out:
#            Clave                            Resumen    Responsable  \
# count      33815                              33815           3303
# unique     33815                              33283             18
# top     CO-34266  : Certificación DTE: LIVEHOST SPA  Jorge Calquín
# freq           1                                 47           1073
#
#             Estado RUT Empresa
# count        33815       27102
# unique          36       14661
# top     Finalizada  76353391-3
# freq         16383          89

# %%
df_certificaciones.sample(3)
# Out:
#           Clave                                            Resumen  \
# 5600   CO-28665  PROD_WEB: Certificación Inicial: CHILE T V CAB...
# 30425   CO-3740           PROD: Certificación Inicial DELYCATE SPA
# 10593  CO-23668  PROD_WEB: Certificación Boleta: INVERSIONES IN...
#
#       Responsable      Estado              Creada         Actualizada  \
# 5600          NaN   Terminado 2021-11-16 07:39:56 2021-11-24 17:40:13
# 30425         NaN    Rejected 2020-01-02 12:13:45 2020-12-30 16:03:34
# 10593         NaN  Finalizada 2021-03-31 20:37:42 2021-04-05 10:02:30
#
#       RUT Empresa
# 5600   96990210-9
# 30425         NaN
# 10593  77050457-0

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Consolidados Pagos TUU**

# %%
df_consolidados = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Consolidado TUU Pagos 2022.xlsx")

# %%
print("Cantidad de registros : ",df_consolidados.shape[0])
print("Cantidad de atributos : ",df_consolidados.shape[1])
# Out:
# Cantidad de registros :  17319
# Cantidad de atributos :  28

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Consolidados Pagos TUU**

# %%
df_consolidados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17319 entries, 0 to 17318
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RUT                      17319 non-null  object
#  1   Razón social             17319 non-null  object
#  2   Código de comercio       17319 non-null  int64
#  3   Código SII               17319 non-null  float64
#  4   Porcentaje comision      17319 non-null  float64
#  5   Comision fija            17319 non-null  float64
#  6   Cantidad TXs             17319 non-null  float64
#  7   Monto Total              17319 non-null  float64
#  8   Comision Neta            17319 non-null  float64
#  9   Comision IVA             17319 non-null  float64
#  10  Tipo                     17319 non-null  object
#  11  Período                  17319 non-null  datetime64[ns]
#  12  Porcentaje comision 2    17319 non-null  float64
#  13  MDR Abril Débito         17319 non-null  float64
#  14  MDR Abril Crédito        17319 non-null  float64
#  15  Costo tx Abril           17319 non-null  float64
#  16  Margen tx Abril          17319 non-null  float64
#  17  MDR Mayo REAL            14821 non-null  float64
#  18  MDR Mayo Supuesto        14821 non-null  float64
#  19  Costo tx Mayo REAL       14821 non-null  float64
#  20  Margen tx Mayo REAL      14821 non-null  float64
#  21  Costo tx Mayo Supuesto   14821 non-null  float64
#  22  Margen tx Mayo Supuesto  17319 non-null  float64
#  23  MCC                      16900 non-null  object
#  24  Partner                  17319 non-null  object
#  25  Categoría Partner        17309 non-null  object
#  26  Tarifa Partner           17319 non-null  float64
#  27  Margen Partner           17319 non-null  float64
# dtypes: datetime64[ns](1), float64(20), int64(1), object(6)
# memory usage: 3.7+ MB

# %%
df_consolidados.describe()
# Out:
#        Código de comercio     Código SII  Porcentaje comision  Comision fija  \
# count        1.731900e+04   17319.000000         17319.000000        17319.0
# mean         5.970395e+11  500666.757838             1.657170            0.0
# std          4.086982e+05  184546.689871             0.553607            0.0
# min          5.970392e+11   11306.000000             0.000000            0.0
# 25%          5.970393e+11  472101.000000             1.290000            0.0
# 50%          5.970393e+11  474100.000000             1.290000            0.0
# 75%          5.970393e+11  561000.000000             2.250000            0.0
# max          5.970406e+11  960909.000000             2.900000            0.0
#
#        Cantidad TXs   Monto Total  Comision Neta   Comision IVA  \
# count  17319.000000  1.731900e+04   17319.000000   17319.000000
# mean     126.724291  1.433976e+06   19524.408684    3710.670131
# std      282.112957  3.051467e+06   40812.801621    7755.479639
# min        1.000000  1.000000e+02       0.000000       0.000000
# 25%        4.000000  6.799500e+04    1217.000000     231.000000
# 50%       22.000000  3.540000e+05    5442.000000    1035.000000
# 75%      113.000000  1.426310e+06   19964.000000    3800.000000
# max     5221.000000  6.179230e+07  797164.000000  151416.000000
#
#        Porcentaje comision 2  MDR Abril Débito  ...  Costo tx Abril  \
# count           17319.000000      17319.000000  ...    17319.000000
# mean                0.016572          0.012083  ...    18793.937244
# std                 0.005536          0.001071  ...    39133.343188
# min                 0.000000          0.005600  ...        0.560000
# 25%                 0.012900          0.011700  ...     1161.020000
# 50%                 0.012900          0.012000  ...     5227.250000
# 75%                 0.022500          0.012700  ...    19182.884500
# max                 0.029000          0.025000  ...   722969.874900
#
#        Margen tx Abril  MDR Mayo REAL  MDR Mayo Supuesto  Costo tx Mayo REAL  \
# count     17319.000000   14821.000000       14821.000000        14821.000000
# mean        730.471440       0.014151           0.014151        18654.139746
# std        6978.346002       0.004417           0.004417        37143.484334
# min     -247634.662500       0.005100           0.005100            0.900000
# 25%           0.913000       0.010700           0.010700         1488.081000
# 50%         120.100000       0.011300           0.011300         5894.200000
# 75%         781.000000       0.019300           0.019300        19732.812100
# max      154081.256000       0.035000           0.035000       698252.956100
#
#        Margen tx Mayo REAL  Costo tx Mayo Supuesto  Margen tx Mayo Supuesto  \
# count         14821.000000            14821.000000             17319.000000
# mean           2725.815116            18654.139746              2332.658111
# std            8867.337013            37143.484334              8258.634385
# min         -207830.951100                0.900000           -207830.951100
# 25%             128.000000             1488.081000                16.580000
# 50%             718.391000             5894.200000               447.800000
# 75%            2852.834000            19732.812100              2263.141000
# max          211239.085000           698252.956100            211239.085000
#
#        Tarifa Partner  Margen Partner
# count    17319.000000    17319.000000
# mean         0.016424      228.403173
# std          0.005470     3994.321917
# min          0.001300  -123458.715000
# 25%          0.012900        0.000000
# 50%          0.012900        0.000000
# 75%          0.022500        0.000000
# max          0.025100   151592.503000
#
# [8 rows x 21 columns]

# %%
df_consolidados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17319 entries, 0 to 17318
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RUT                      17319 non-null  object
#  1   Razón social             17319 non-null  object
#  2   Código de comercio       17319 non-null  int64
#  3   Código SII               17319 non-null  float64
#  4   Porcentaje comision      17319 non-null  float64
#  5   Comision fija            17319 non-null  float64
#  6   Cantidad TXs             17319 non-null  float64
#  7   Monto Total              17319 non-null  float64
#  8   Comision Neta            17319 non-null  float64
#  9   Comision IVA             17319 non-null  float64
#  10  Tipo                     17319 non-null  object
#  11  Período                  17319 non-null  datetime64[ns]
#  12  Porcentaje comision 2    17319 non-null  float64
#  13  MDR Abril Débito         17319 non-null  float64
#  14  MDR Abril Crédito        17319 non-null  float64
#  15  Costo tx Abril           17319 non-null  float64
#  16  Margen tx Abril          17319 non-null  float64
#  17  MDR Mayo REAL            14821 non-null  float64
#  18  MDR Mayo Supuesto        14821 non-null  float64
#  19  Costo tx Mayo REAL       14821 non-null  float64
#  20  Margen tx Mayo REAL      14821 non-null  float64
#  21  Costo tx Mayo Supuesto   14821 non-null  float64
#  22  Margen tx Mayo Supuesto  17319 non-null  float64
#  23  MCC                      16900 non-null  object
#  24  Partner                  17319 non-null  object
#  25  Categoría Partner        17309 non-null  object
#  26  Tarifa Partner           17319 non-null  float64
#  27  Margen Partner           17319 non-null  float64
# dtypes: datetime64[ns](1), float64(20), int64(1), object(6)
# memory usage: 3.7+ MB

# %%
df_consolidados.describe()
# Out:
#        Código de comercio     Código SII  Porcentaje comision  Comision fija  \
# count        1.731900e+04   17319.000000         17319.000000        17319.0
# mean         5.970395e+11  500666.757838             1.657170            0.0
# std          4.086982e+05  184546.689871             0.553607            0.0
# min          5.970392e+11   11306.000000             0.000000            0.0
# 25%          5.970393e+11  472101.000000             1.290000            0.0
# 50%          5.970393e+11  474100.000000             1.290000            0.0
# 75%          5.970393e+11  561000.000000             2.250000            0.0
# max          5.970406e+11  960909.000000             2.900000            0.0
#
#        Cantidad TXs   Monto Total  Comision Neta   Comision IVA  \
# count  17319.000000  1.731900e+04   17319.000000   17319.000000
# mean     126.724291  1.433976e+06   19524.408684    3710.670131
# std      282.112957  3.051467e+06   40812.801621    7755.479639
# min        1.000000  1.000000e+02       0.000000       0.000000
# 25%        4.000000  6.799500e+04    1217.000000     231.000000
# 50%       22.000000  3.540000e+05    5442.000000    1035.000000
# 75%      113.000000  1.426310e+06   19964.000000    3800.000000
# max     5221.000000  6.179230e+07  797164.000000  151416.000000
#
#        Porcentaje comision 2  MDR Abril Débito  ...  Costo tx Abril  \
# count           17319.000000      17319.000000  ...    17319.000000
# mean                0.016572          0.012083  ...    18793.937244
# std                 0.005536          0.001071  ...    39133.343188
# min                 0.000000          0.005600  ...        0.560000
# 25%                 0.012900          0.011700  ...     1161.020000
# 50%                 0.012900          0.012000  ...     5227.250000
# 75%                 0.022500          0.012700  ...    19182.884500
# max                 0.029000          0.025000  ...   722969.874900
#
#        Margen tx Abril  MDR Mayo REAL  MDR Mayo Supuesto  Costo tx Mayo REAL  \
# count     17319.000000   14821.000000       14821.000000        14821.000000
# mean        730.471440       0.014151           0.014151        18654.139746
# std        6978.346002       0.004417           0.004417        37143.484334
# min     -247634.662500       0.005100           0.005100            0.900000
# 25%           0.913000       0.010700           0.010700         1488.081000
# 50%         120.100000       0.011300           0.011300         5894.200000
# 75%         781.000000       0.019300           0.019300        19732.812100
# max      154081.256000       0.035000           0.035000       698252.956100
#
#        Margen tx Mayo REAL  Costo tx Mayo Supuesto  Margen tx Mayo Supuesto  \
# count         14821.000000            14821.000000             17319.000000
# mean           2725.815116            18654.139746              2332.658111
# std            8867.337013            37143.484334              8258.634385
# min         -207830.951100                0.900000           -207830.951100
# 25%             128.000000             1488.081000                16.580000
# 50%             718.391000             5894.200000               447.800000
# 75%            2852.834000            19732.812100              2263.141000
# max          211239.085000           698252.956100            211239.085000
#
#        Tarifa Partner  Margen Partner
# count    17319.000000    17319.000000
# mean         0.016424      228.403173
# std          0.005470     3994.321917
# min          0.001300  -123458.715000
# 25%          0.012900        0.000000
# 50%          0.012900        0.000000
# 75%          0.022500        0.000000
# max          0.025100   151592.503000
#
# [8 rows x 21 columns]

# %%
df_consolidados.describe(include = "object")
# Out:
#                RUT                                   Razón social    Tipo  \
# count        17319                                          17319   17319
# unique        2955                                           3017       2
# top     74828100-2  FUND JARDIN BOTANICO NACIONAL DE VINA DEL MAR  DEBITO
# freq            60                                             60   10178
#
#                   MCC     Partner Categoría Partner
# count           16900       17319             17309
# unique             86          31                 5
# top     SUPERMERCADOS  No Partner        No Partner
# freq             3334       15568             15568

# %%
df_consolidados["aux_rut"] = df_consolidados["RUT"].apply(lambda x : validarRut(x))

# %%
df_consolidados["aux_rut"].value_counts()
# Out:
# True    17319
# Name: aux_rut, dtype: int64

# %%
df_consolidados["RUT"].value_counts()
# Out:
# 74828100-2    60
# 76795561-8    46
# 76544003-3    39
# 76938573-8    38
# 78067040-1    38
#               ..
# 76513949-K     1
# 76510731-8     1
# 76505877-5     1
# 10134744-3     1
# 77525046-1     1
# Name: RUT, Length: 2955, dtype: int64

# %%
df_consolidados.RUT.nunique()
# Out:
# 2955

# %%
df_consolidados.Período.value_counts()
# Out:
# 2022-05-01    4897
# 2022-04-01    4079
# 2022-03-01    3366
# 2022-02-01    2731
# 2022-01-01    2246
# Name: Período, dtype: int64

# %%
df_consolidados.columns
# Out:
# Index(['RUT', 'Razón social', 'Código de comercio', 'Código SII',
#        'Porcentaje comision', 'Comision fija', 'Cantidad TXs', 'Monto Total',
#        'Comision Neta', 'Comision IVA', 'Tipo', 'Período',
#        'Porcentaje comision 2', 'MDR Abril Débito', 'MDR Abril Crédito',
#        'Costo tx Abril', 'Margen tx Abril', 'MDR Mayo REAL',
#        'MDR Mayo Supuesto', 'Costo tx Mayo REAL', 'Margen tx Mayo REAL',
#        'Costo tx Mayo Supuesto', 'Margen tx Mayo Supuesto', 'MCC', 'Partner',
#        'Categoría Partner', 'Tarifa Partner', 'Margen Partner', 'aux_rut'],
#       dtype='object')

# %%
df_consolidados_aux = df_consolidados.copy()
df_consolidados_aux.drop(columns = ["Código de comercio", "Período", "Porcentaje comision 2", 'MDR Abril Débito', 'MDR Abril Crédito',
       'Costo tx Abril', 'Margen tx Abril', 'MDR Mayo REAL',
       'MDR Mayo Supuesto', 'Costo tx Mayo REAL', 'Margen tx Mayo REAL',
       'Costo tx Mayo Supuesto', 'Margen tx Mayo Supuesto', "Tarifa Partner", "Margen Partner", "aux_rut"], inplace = True)

# %%
df_consolidados_aux.sample(2)
# Out:
#               RUT                                       Razón social  \
# 11951  77182313-0   PELUCHI PET SHOP SEBASTIAN ARNES ADRIAN E.I.R.L.
# 16721  77526165-K  COMIDA AL PASO JOAQUIN ESTEBAN PINCHEIRA LAGOS...
#
#        Código SII  Porcentaje comision  Comision fija  Cantidad TXs  \
# 11951    477391.0                 1.29            0.0          72.0
# 16721    561000.0                 2.25            0.0           5.0
#
#        Monto Total  Comision Neta  Comision IVA     Tipo  \
# 11951    1493100.0        19259.0        3665.0   DEBITO
# 16721      63150.0         1420.0         270.0  CREDITO
#
#                         MCC     Partner Categoría Partner
# 11951   ANIMALES DOMESTICOS  No Partner        No Partner
# 16721  RESTAURANT FAST FOOD  No Partner        No Partner

# %%
df_consolidados_aux.rename(columns = {"Razón social":"razonSocial", "Código SII":"codSII", "Porcentaje comision":"porcentajeComision", "Comision fija":"comisionFija",
                                  "Cantidad TXs":"cantidadTransacciones", "Monto Total":"montoTotal", "Comision Neta":"comisionNeta",
                                  "Comision IVA":"comisionIVA", "Categoría Partner":"categoriaPartner"}, inplace = True)

# %%
df_consolidados_aux.sample(2)
# Out:
#               RUT                    razonSocial    codSII  \
# 6866    8869178-4  LUIS ALBERTO PAREDES GONZALEZ  472101.0
# 11757  77113226-K               LIZANA ARAYA SPA  472200.0
#
#        porcentajeComision  comisionFija  cantidadTransacciones  montoTotal  \
# 6866                 1.39           0.0                    3.0      3000.0
# 11757                1.29           0.0                  232.0   1139570.0
#
#        comisionNeta  comisionIVA    Tipo                MCC     Partner  \
# 6866           42.0          9.0  DEBITO      SUPERMERCADOS  No Partner
# 11757       14694.0       2783.0  DEBITO  BOTILLERIAS,VINAS  No Partner
#
#       categoriaPartner
# 6866        No Partner
# 11757       No Partner

# %%
df_consolidados_aux.shape
# Out:
# (17319, 13)

# %%
df_consolidados_aux.codSII.value_counts()
# Out:
# 472101.0    3105
# 561000.0    1971
# 107100.0     632
# 472109.0     370
# 960200.0     370
#             ...
# 476102.0       1
# 949909.0       1
# 12900.0        1
# 742001.0       1
# 370000.0       1
# Name: codSII, Length: 249, dtype: int64

# %%
def getfreqcred(rut):
  df_rut = df_consolidados_aux[df_consolidados_aux["RUT"] == rut]
  return df_rut[df_rut["Tipo"] == "CREDITO"].shape[0]

# %%
def getfreqdeb(rut):
  df_rut = df_consolidados_aux[df_consolidados_aux["RUT"] == rut]
  return df_rut[df_rut["Tipo"] == "DEBITO"].shape[0]

# %%
df_montoTotal = df_consolidados_aux.groupby(['RUT'])['montoTotal'].sum().to_frame().reset_index()
df_cantTxs = df_consolidados_aux.groupby(['RUT'])['cantidadTransacciones'].sum().to_frame().reset_index()
df_neta = df_consolidados_aux.groupby(['RUT'])['comisionNeta'].sum().to_frame().reset_index()
df_iva = df_consolidados_aux.groupby(['RUT'])['comisionIVA'].sum().to_frame().reset_index()
df_porcentajeComision = df_consolidados_aux.groupby(['RUT'])["porcentajeComision"].mean().to_frame()

# %%
categorical_cols = ["codSII", 'MCC', 'Partner', 'categoriaPartner']
lencoder = LabelEncoder()
for col in categorical_cols :
  df_consolidados_aux[col] = df_consolidados_aux[[col]].apply(lencoder.fit_transform)

# %%
df_consolidados_aux.drop(columns = ["montoTotal", "cantidadTransacciones", "comisionNeta", "comisionIVA", "porcentajeComision", "comisionFija", "razonSocial"], inplace = True)

# %%
df_consolidados_aux
# Out:
#               RUT  codSII     Tipo  MCC  Partner  categoriaPartner
# 0      10018933-K      23   DEBITO   48        0                 3
# 1      10037348-3     116   DEBITO   11        0                 3
# 2      10037348-3     116   DEBITO   11        0                 3
# 3      10049357-8     107   DEBITO   74        0                 3
# 4      10054812-7     173   DEBITO   66       24                 2
# ...           ...     ...      ...  ...      ...               ...
# 17314   9985572-K      18   DEBITO   57       28                 4
# 17315   9985572-K      18   DEBITO   57       28                 4
# 17316   9988020-1      18   DEBITO   57        0                 3
# 17317   9999023-6     112  CREDITO   48        0                 3
# 17318   9999023-6     112   DEBITO   48        0                 3
#
# [17319 rows x 6 columns]

# %%
df_consolidados_aux["debito"] = df_consolidados_aux["RUT"].apply(lambda x : getfreqdeb(x))
df_consolidados_aux["credito"] = df_consolidados_aux["RUT"].apply(lambda x : getfreqcred(x))

# %%
df_consolidados_aux.drop(columns = ["Tipo"], inplace = True)

# %%
df_debito = df_consolidados_aux.groupby(['RUT'])["debito"].mean().to_frame()
df_credito = df_consolidados_aux.groupby(['RUT'])["credito"].mean().to_frame()

# %%
df_aux = df_consolidados_aux.copy()
df_aux.drop_duplicates(inplace = True)

# %%
df_aux
# Out:
#               RUT  codSII  MCC  Partner  categoriaPartner  debito  credito
# 0      10018933-K      23   48        0                 3       5        4
# 1      10037348-3     116   11        0                 3       8        6
# 3      10049357-8     107   74        0                 3       5        5
# 4      10054812-7     173   66       24                 2       3        0
# 5      10056607-9     110   74        0                 3       5        4
# ...           ...     ...  ...      ...               ...     ...      ...
# 17287   9751797-5     110   74       17                 2       1        0
# 17294   9789513-9     114   57        0                 3       1        0
# 17302   9836941-4     110   74        0                 3       1        0
# 17305   9846371-2     111   13       29                 4       1        1
# 17314   9985572-K      18   57       28                 4       2        0
#
# [3003 rows x 7 columns]

# %% [markdown]
# *Se opta por eliminar los rut duplicados para la primera iteración, posteriormente se espera buscar una forma de tratar aquellos comercios que contengan más de un MCC / código servicio impuestos internos*

# %%
df_aux.drop_duplicates(subset = "RUT", keep="first", inplace = True)

# %%
df_aux
# Out:
#               RUT  codSII  MCC  Partner  categoriaPartner  debito  credito
# 0      10018933-K      23   48        0                 3       5        4
# 1      10037348-3     116   11        0                 3       8        6
# 3      10049357-8     107   74        0                 3       5        5
# 4      10054812-7     173   66       24                 2       3        0
# 5      10056607-9     110   74        0                 3       5        4
# ...           ...     ...  ...      ...               ...     ...      ...
# 17287   9751797-5     110   74       17                 2       1        0
# 17294   9789513-9     114   57        0                 3       1        0
# 17302   9836941-4     110   74        0                 3       1        0
# 17305   9846371-2     111   13       29                 4       1        1
# 17314   9985572-K      18   57       28                 4       2        0
#
# [2955 rows x 7 columns]

# %%
data_frames = [df_montoTotal, df_cantTxs, df_neta, df_iva, df_porcentajeComision, df_debito, df_credito, df_aux]

# %%
from functools import reduce
df_consolidados_merge = reduce(lambda  left,right: pd.merge(left,right,on=['RUT']), data_frames)

# %%
df_consolidados_merge['montoTotal'] = df_consolidados_merge['montoTotal'].astype(int)
df_consolidados_merge['cantidadTransacciones'] = df_consolidados_merge['cantidadTransacciones'].astype(int)
df_consolidados_merge['comisionNeta'] = df_consolidados_merge['comisionNeta'].astype(int)
df_consolidados_merge['comisionIVA'] = df_consolidados_merge['comisionIVA'].astype(int)

# %%
df_consolidados_merge.sample(3)
# Out:
#              RUT  montoTotal  cantidadTransacciones  comisionNeta  \
# 1006   6133970-1      407930                     28          5262
# 2126  77396487-4     8318309                   1491        112037
# 1777  77168114-K    18920834                    956        260825
#
#       comisionIVA  porcentajeComision  debito_x  credito_x  codSII  MCC  \
# 1006         1001                1.29       1.0        0.0     173   66
# 2126        21285                1.90       2.0        2.0     116   11
# 1777        49576                1.89       5.0        5.0     142    3
#
#       Partner  categoriaPartner  debito_y  credito_y
# 1006        0                 3         1          0
# 2126        0                 3         2          2
# 1777        0                 3         5          5

# %%
df_consolidados_merge["porcentajeComision"] = df_consolidados_merge["porcentajeComision"].round(decimals = 2)

# %%
df_consolidados_merge
# Out:
#              RUT  montoTotal  cantidadTransacciones  comisionNeta  \
# 0     10006728-5      209000                      8          2697
# 1     10007508-3         300                      2             4
# 2     10011781-9     8410468                    387        118884
# 3     10018933-K     4526000                    178         55777
# 4     10024696-1      927100                     89         13335
# ...          ...         ...                    ...           ...
# 2950   9974219-4    11297545                   1194        141104
# 2951   9979750-9     1270180                    515         13431
# 2952   9985572-K      891200                    124         10065
# 2953   9988020-1    27783870                    840        319914
# 2954   9999023-6     4078245                    516         55612
#
#       comisionIVA  porcentajeComision  debito_x  credito_x  codSII  MCC  \
# 0             513                1.29       1.0        0.0     142    3
# 1               1                1.29       1.0        0.0     111   13
# 2           22577                1.88       4.0        3.0     111   13
# 3           10587                1.63       5.0        4.0      23   48
# 4            2536                1.90       2.0        2.0     109   86
# ...           ...                 ...       ...        ...     ...  ...
# 2950        26821                1.69       3.0        3.0     154   48
# 2951         2583                1.50       5.0        5.0     114   57
# 2952         1916                1.13       2.0        0.0      18   57
# 2953        60777                1.45       5.0        4.0      18   57
# 2954        10567                1.80       5.0        5.0     112   48
#
#       Partner  categoriaPartner  debito_y  credito_y
# 0           0                 3         1          0
# 1           0                 3         1          0
# 2          11                 4         4          3
# 3           0                 3         5          4
# 4           0                 3         2          2
# ...       ...               ...       ...        ...
# 2950        0                 3         3          3
# 2951        0                 3         5          5
# 2952       28                 4         2          0
# 2953        0                 3         5          4
# 2954        0                 3         5          5
#
# [2955 rows x 14 columns]

# %%
df_consolidados_merge.drop(columns = ["debito_x", "credito_x"], inplace=True)

# %%
df_consolidados_merge.rename(columns = {"credito_y":"credito", "debito_y":"debito"}, inplace = True)

# %%
df_consolidados_merge
# Out:
#              RUT  montoTotal  cantidadTransacciones  comisionNeta  \
# 0     10006728-5      209000                      8          2697
# 1     10007508-3         300                      2             4
# 2     10011781-9     8410468                    387        118884
# 3     10018933-K     4526000                    178         55777
# 4     10024696-1      927100                     89         13335
# ...          ...         ...                    ...           ...
# 2950   9974219-4    11297545                   1194        141104
# 2951   9979750-9     1270180                    515         13431
# 2952   9985572-K      891200                    124         10065
# 2953   9988020-1    27783870                    840        319914
# 2954   9999023-6     4078245                    516         55612
#
#       comisionIVA  porcentajeComision  codSII  MCC  Partner  categoriaPartner  \
# 0             513                1.29     142    3        0                 3
# 1               1                1.29     111   13        0                 3
# 2           22577                1.88     111   13       11                 4
# 3           10587                1.63      23   48        0                 3
# 4            2536                1.90     109   86        0                 3
# ...           ...                 ...     ...  ...      ...               ...
# 2950        26821                1.69     154   48        0                 3
# 2951         2583                1.50     114   57        0                 3
# 2952         1916                1.13      18   57       28                 4
# 2953        60777                1.45      18   57        0                 3
# 2954        10567                1.80     112   48        0                 3
#
#       debito  credito
# 0          1        0
# 1          1        0
# 2          4        3
# 3          5        4
# 4          2        2
# ...      ...      ...
# 2950       3        3
# 2951       5        5
# 2952       2        0
# 2953       5        4
# 2954       5        5
#
# [2955 rows x 12 columns]

# %%
df_consolidados_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2955 entries, 0 to 2954
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RUT                    2955 non-null   object
#  1   montoTotal             2955 non-null   int64
#  2   cantidadTransacciones  2955 non-null   int64
#  3   comisionNeta           2955 non-null   int64
#  4   comisionIVA            2955 non-null   int64
#  5   porcentajeComision     2955 non-null   float64
#  6   codSII                 2955 non-null   int64
#  7   MCC                    2955 non-null   int64
#  8   Partner                2955 non-null   int64
#  9   categoriaPartner       2955 non-null   int64
#  10  debito                 2955 non-null   int64
#  11  credito                2955 non-null   int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 300.1+ KB

# %%
df_consolidados_merge.describe()
# Out:
#          montoTotal  cantidadTransacciones  comisionNeta   comisionIVA  \
# count  2.955000e+03            2955.000000  2.955000e+03  2.955000e+03
# mean   8.404412e+06             742.720135  1.144309e+05  2.174792e+04
# std    2.001466e+07            1637.164655  2.815907e+05  5.351479e+04
# min    1.000000e+02               1.000000  0.000000e+00  0.000000e+00
# 25%    4.504975e+05              31.000000  5.856500e+03  1.113500e+03
# 50%    2.410650e+06             187.000000  3.181000e+04  6.044000e+03
# 75%    7.889906e+06             725.000000  1.064580e+05  2.021850e+04
# max    3.653484e+08           24262.000000  5.802891e+06  1.102355e+06
#
#        porcentajeComision       codSII          MCC      Partner  \
# count         2955.000000  2955.000000  2955.000000  2955.000000
# mean             1.604660   128.821997    51.572927     1.822335
# std              0.287927    53.455910    24.476503     5.991806
# min              0.130000     0.000000     0.000000     0.000000
# 25%              1.390000   110.000000    36.000000     0.000000
# 50%              1.680000   116.000000    57.000000     0.000000
# 75%              1.800000   173.000000    74.000000     0.000000
# max              2.900000   248.000000    86.000000    30.000000
#
#        categoriaPartner       debito      credito
# count       2955.000000  2955.000000  2955.000000
# mean           2.987817     3.444332     2.416582
# std            0.516997     2.312545     2.355376
# min            0.000000     0.000000     0.000000
# 25%            3.000000     2.000000     1.000000
# 50%            3.000000     3.000000     2.000000
# 75%            3.000000     5.000000     4.000000
# max            5.000000    30.000000    30.000000

# %%
# Visualización de todas las variables sin las variables categóricas con mas de 10 valores únicos
rows = 12; cols = round(df_consolidados.shape[1]/rows)
plt.figure(figsize=(15,30))
for i,j in enumerate(df_consolidados_merge.columns):
    plt.subplot(rows, cols, i+1)
    if df_consolidados_merge[j].dtype == 'object':
        sns.countplot(df_consolidados_merge[j])
        plt.xticks(rotation=45)
    else:
        if len(df_consolidados_merge[j].value_counts())>2:
            sns.distplot(df_consolidados_merge[j],rug=True,fit=stats.norm)    
            plt.axvline(df_consolidados_merge[j].mean(), color = "tomato", linestyle = '--')
        else:
            sns.countplot(df_consolidados_merge[j])
    plt.tight_layout()

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Facturación y pagos clientes TUU**

# %%
df_facturacion_sheetcl = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Facturación y pagos clientes TUU.xlsx", "Cliente Tuu")

# %%
df_facturacion_sheetcl.columns
# Out:
# Index(['Rut', 'Rut dv', 'Rut sdv', 'Email', 'Whmcs', 'Workspace', 'Plan',
#        'Organizacion', 'Facturación', 'Pagos', 'F2', 'P2'],
#       dtype='object')

# %%
print("Cantidad de registros : ",df_facturacion_sheetcl.shape[0])
print("Cantidad de atributos : ",df_facturacion_sheetcl.shape[1])
# Out:
# Cantidad de registros :  4010
# Cantidad de atributos :  12

# %%
df_facturacion_sheetpag = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Pagos.xlsx")

# %%
print("Cantidad de registros : ",df_facturacion_sheetpag.shape[0])
print("Cantidad de atributos : ",df_facturacion_sheetpag.shape[1])
# Out:
# Cantidad de registros :  17539
# Cantidad de atributos :  5

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Facturación y pagos clientes TUU**

# %%
df_facturacion_sheetcl.sample(3)
# Out:
#             Rut      Rut dv   Rut sdv                             Email  \
# 3913  77420198K  77420198-K  77420198        tienditapalondra@gmail.com
# 3956  77528823K  77528823-K  77528823  centroodontologicosana@gmail.com
# 2796  773048975  77304897-5  77304897        contacto.mdrinks@gmail.com
#
#          Whmcs  Workspace      Plan                Organizacion  Facturación  \
# 3913  105632.0    17671.0  Plan Tuu          Torres Y Rojas Spa          NaN
# 3956  101817.0    17058.0  Plan Tuu  Sociedad Odontologica Asva          NaN
# 2796  100869.0    16940.0  Plan Tuu               Middel Drinks          NaN
#
#               Pagos      F2       P2
# 3913  Realiza Pagos  d. 3MM   c. 1MM
# 3956  Realiza Pagos  c. 1MM   c. 1MM
# 2796  Realiza Pagos  c. 1MM  e. 10MM

# %%
df_facturacion_sheetcl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4010 entries, 0 to 4009
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rut           4010 non-null   object
#  1   Rut dv        4010 non-null   object
#  2   Rut sdv       4010 non-null   int64
#  3   Email         4010 non-null   object
#  4   Whmcs         4010 non-null   float64
#  5   Workspace     4010 non-null   float64
#  6   Plan          4010 non-null   object
#  7   Organizacion  4010 non-null   object
#  8   Facturación   0 non-null      float64
#  9   Pagos         2832 non-null   object
#  10  F2            4010 non-null   object
#  11  P2            4010 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 376.1+ KB

# %%
df_facturacion_sheetpag.sample(3)
# Out:
#              RUT     Tipo    Periodo  CantidadTXs  MontoTotal
# 7104  17980832-3   Débito 2022-03-01        321.0   2496040.0
# 8586  10407446-4  Crédito 2022-04-01          3.0      8800.0
# 6246  77428676-4  Crédito 2022-03-01          2.0     41150.0

# %%
df_facturacion_sheetpag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17539 entries, 0 to 17538
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RUT          17539 non-null  object
#  1   Tipo         17539 non-null  object
#  2   Periodo      17539 non-null  datetime64[ns]
#  3   CantidadTXs  17539 non-null  float64
#  4   MontoTotal   17539 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 685.2+ KB

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Incidencias**

# %%
df_incidencias = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Incidencias Christian RPA- HES.xlsx", "IncidenciasHES")

# %%
df_incidencias.columns
# Out:
# Index(['Clave', 'Resumen', 'Responsable', 'Informador', 'Estado', 'Creada',
#        'Actualizada', 'Cuenta correo origen (Envía)',
#        'Cuentas de Email con Problemas', 'Descripción', 'DTE con Problemas',
#        'Email asociado a la compra', 'Email Cliente', 'ID Dispositivo',
#        'Nombre Cliente', 'RUT asociado a la firma', 'RUT Empresa', 'Telefono',
#        'Periodo'],
#       dtype='object')

# %%
print("Cantidad de registros : ",df_incidencias.shape[0])
print("Cantidad de atributos : ",df_incidencias.shape[1])
# Out:
# Cantidad de registros :  12471
# Cantidad de atributos :  19

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Incidencias**

# %%
df_incidencias.sample(3)
# Out:
#          Clave                     Resumen     Responsable  \
# 5533  HES-7004    [openfactura] 11402644-1  Juan Gutierrez
# 5564  HES-6973               [openfactura]     Diego Palma
# 8350  HES-4182  [Opencloud] 186.64.122.166    Diego Moraga
#
#                     Informador      Estado              Creada  \
# 5533              Gustavo Moya  Finalizada 2021-09-30 16:54:26
# 5564        carlos.ballesteros  Finalizada 2021-09-29 16:02:12
# 8350  Leandro Jesus Colmenarez     Cerrada 2021-06-21 16:15:35
#
#              Actualizada Cuenta correo origen (Envía)  \
# 5533 2021-10-28 10:31:46                          NaN
# 5564 2021-10-06 16:54:55                          NaN
# 8350 2021-06-22 11:59:41                          NaN
#
#      Cuentas de Email con Problemas  \
# 5533                            NaN
# 5564                            NaN
# 8350                            NaN
#
#                                             Descripción  \
# 5533  Cliente indica que los documentos emitidos des...
# 5564  cliente no puede emitir facturas ni desde el p...
# 8350  Cliente indica que al loguearse el root no le ...
#
#                DTE con Problemas Email asociado a la compra  \
# 5533                         NaN                        NaN
# 5564  DTE 33 Factura Electrónica                        NaN
# 8350                         NaN                        NaN
#
#                       Email Cliente ID Dispositivo  \
# 5533  gustavoquijadacsm@hotmail.com            NaN
# 5564      oficinacentral@hotmail.es            NaN
# 8350           drsnipiwih@gmail.com            NaN
#
#                    Nombre Cliente RUT asociado a la firma RUT Empresa  \
# 5533     Gustavo Quijada Castillo                     NaN  11402644-1
# 5564   JOSE EUGENIO MUNOZ LABARCA                     NaN   6921192-5
# 8350                 Carlos Paiva                     NaN         NaN
#
#                             Telefono    Periodo
# 5533                  +569 6919 2700 2021-09-01
# 5564                    +56949912910 2021-09-01
# 8350  0056982837129 // 0056981647039 2021-06-01

# %%
df_incidencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7545 entries, 0 to 12468
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Clave                           7545 non-null   object
#  1   Resumen                         7545 non-null   object
#  2   Responsable                     7395 non-null   object
#  3   Informador                      7545 non-null   object
#  4   Estado                          7545 non-null   object
#  5   Creada                          7545 non-null   datetime64[ns]
#  6   Actualizada                     7545 non-null   datetime64[ns]
#  7   Cuenta correo origen (Envía)    0 non-null      object
#  8   Cuentas de Email con Problemas  0 non-null      object
#  9   Descripción                     7525 non-null   object
#  10  DTE con Problemas               1469 non-null   object
#  11  Email asociado a la compra      1478 non-null   object
#  12  Email Cliente                   7275 non-null   object
#  13  ID Dispositivo                  971 non-null    object
#  14  Nombre Cliente                  7394 non-null   object
#  15  RUT asociado a la firma         0 non-null      object
#  16  RUT Empresa                     7545 non-null   object
#  17  Telefono                        7180 non-null   object
#  18  Periodo                         6338 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), object(16)
# memory usage: 1.2+ MB

# %%
df_incidencias["RUT Empresa"].value_counts()
# Out:
# 5213839-6     16
# 76975135-1    16
# 69040700-0    16
# 76540930-6    13
# 76974235-2    12
#               ..
# 16040374-9     1
# 6750600-6      1
# 18252990-7     1
# 10691348-k     1
# 76905828       1
# Name: RUT Empresa, Length: 5314, dtype: int64

# %%
df_incidencias = df_incidencias[df_incidencias['RUT Empresa'].notna()]

# %%
df_incidencias["RUT Empresa"].isna().sum()
# Out:
# 0

# %%
df_incidencias
# Out:
#            Clave                                Resumen      Responsable  \
# 0      HES-12573  [CambioCorreoEspacio] RUT: 12731763-1              NaN
# 1      HES-12572               [OpenFactura] 77159914-1    Jorge Caceres
# 3      HES-12570                    [SIMPLE] 76869731-0    Jorge Caceres
# 4      HES-12569                       [TUU] 16429541-9  Fernanda Parras
# 6      HES-12567                       [TUU] 11891533-K              NaN
# ...          ...                                    ...              ...
# 12464     HES-59               [openfactura] 77020975-7   Juan Gutierrez
# 12465     HES-58                [opefactura ]76743832-K     Fabian Rubio
# 12466     HES-57                [opefactura ]76860171-2     Fabian Rubio
# 12467     HES-56                [openfactura] 7996710-6     Fabian Rubio
# 12468     HES-55                     [Haulmer] 76905828     Fabian Rubio
#
#                           Informador            Estado              Creada  \
# 0      Claudio Ignacio Arias Bastias  Tareas por hacer 2022-06-13 13:47:28
# 1                       Carlos Rojas         In Review 2022-06-13 13:40:46
# 3                       Gustavo Moya         In Review 2022-06-13 12:55:21
# 4                     Rodrigo Gilles  Tareas por hacer 2022-06-13 12:11:57
# 6                     Rodrigo Gilles           Urgente 2022-06-13 11:36:57
# ...                              ...               ...                 ...
# 12464                Gonzalo Labarca        Finalizada 2020-12-02 15:35:23
# 12465                 Pedro Saavedra        Finalizada 2020-12-02 14:06:04
# 12466                 Pedro Saavedra        Finalizada 2020-12-02 14:00:59
# 12467                 Pedro Saavedra        Finalizada 2020-12-02 13:56:22
# 12468                    Brian Salas        Finalizada 2020-12-02 10:08:49
#
#               Actualizada Cuenta correo origen (Envía)  \
# 0     2022-06-13 13:52:19                          NaN
# 1     2022-06-13 14:05:04                          NaN
# 3     2022-06-13 13:50:04                          NaN
# 4     2022-06-13 12:51:55                          NaN
# 6     2022-06-13 11:37:01                          NaN
# ...                   ...                          ...
# 12464 2021-01-06 18:08:38                          NaN
# 12465 2021-01-06 18:08:37                          NaN
# 12466 2021-01-06 18:08:41                          NaN
# 12467 2021-01-06 18:08:39                          NaN
# 12468 2021-01-06 18:08:43                          NaN
#
#       Cuentas de Email con Problemas  \
# 0                                NaN
# 1                                NaN
# 3                                NaN
# 4                                NaN
# 6                                NaN
# ...                              ...
# 12464                            NaN
# 12465                            NaN
# 12466                            NaN
# 12467                            NaN
# 12468                            NaN
#
#                                              Descripción  \
# 0      Cliente solicita cambiar el correo vinculado a...
# 1      Cliente con servicio suspendido (no desea reno...
# 3      Cliente emite desde el pos, el día 28 de mayo ...
# 4      Cliente indica que desde el día miércoles 8 de...
# 6      Cliente indica que todos estos meses a pagados...
# ...                                                  ...
# 12464  Cliente indica que la boleta emitida el dia 29...
# 12465  el cliente señala que las facturas de compra s...
# 12466  cliente señala que las facturas de los proveed...
# 12467  cliente indica que sus documentos dte 39 no se...
# 12468  El cliente informa que no muestra ningún docum...
#
#                 DTE con Problemas Email asociado a la compra  \
# 0                             NaN                        NaN
# 1       DTE 39 Boleta Electrónica                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# 6                             NaN                        NaN
# ...                           ...                        ...
# 12464                         NaN                        NaN
# 12465  DTE 33 Factura Electrónica                        NaN
# 12466    DTE 46 Factura de Compra                        NaN
# 12467   DTE 39 Boleta Electrónica                        NaN
# 12468  DTE 33 Factura Electrónica                        NaN
#
#                               Email Cliente ID Dispositivo  \
# 0                   finanzas@empresasrvc.cl            NaN
# 1      enixtecnologiaycomputacion@gmail.com            NaN
# 3             contacto@opticasclubvision.cl            NaN
# 4          jmanuel.alvarez.osorio@gmail.com            NaN
# 6                  salvadorvale71@gmail.com            NaN
# ...                                     ...            ...
# 12464            javier.stevens.c@gmail.com           3522
# 12465            diego.naranjo@exporteas.cl            NaN
# 12466              rivero.liliana@gmail.com            NaN
# 12467           \toscar.figueroa@bmxshop.cl            NaN
# 12468                   ns.motork@gmail.com            NaN
#
#                           Nombre Cliente RUT asociado a la firma RUT Empresa  \
# 0                          Ricardo Vidal                     NaN  12731763-1
# 1                          Alberto Rivas                     NaN  77159914-1
# 3                  Chrtian Silva Escobar                     NaN  76869731-0
# 4          MANUEL ALEJANDRO ALVAREZ JARA                     NaN  16429541-9
# 6      SALVADOR SEGUNDO VALENZUELA SALAS                     NaN  11891533-K
# ...                                  ...                     ...         ...
# 12464                     Javier Stevens                     NaN  77020975-7
# 12465                        diego diego                     NaN  76743832-K
# 12466                        Rina RIvero                     NaN  76860171-2
# 12467                     OSCAR FIGUEROA                     NaN   7996710-6
# 12468              alexis nicolas kappes                     NaN    76905828
#
#              Telefono    Periodo
# 0           941709754 2022-06-01
# 1      +56 9 65634449 2022-06-01
# 3      +56 9 71067982 2022-06-01
# 4      +569 8124 8918 2022-06-01
# 6        +56945469089 2022-06-01
# ...               ...        ...
# 12464   +569 99989197        NaT
# 12465   +56.976176077        NaT
# 12466       998204511        NaT
# 12467   +56.976991334        NaT
# 12468   0056940752520        NaT
#
# [7545 rows x 19 columns]

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Planes clientes directos**

# %%
df_directos = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Planes clientes directos.xlsx")

# %%
df_directos.columns
# Out:
# Index(['EMAIL', 'WHMCS', 'WORKSPACE', 'RUT', 'Plan Tuu', 'ORGANIZACION'], dtype='object')

# %%
print("Cantidad de registros : ",df_directos.shape[0])
print("Cantidad de atributos : ",df_directos.shape[1])
# Out:
# Cantidad de registros :  13571
# Cantidad de atributos :  6

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Planes clientes directos**

# %%
df_directos.sample(3)
# Out:
#                               EMAIL    WHMCS  WORKSPACE          RUT Plan Tuu  \
# 1843             jgcgruas@gmail.com  49731.0     3053.0  144811917.0   Simple
# 7649  gustavoquijadacsm@hotmail.com   6663.0    12882.0  114026441.0   Simple
# 9280       ignaciosheazul@gmail.com  87495.0    15360.0  199403532.0   Simple
#
#                         ORGANIZACION
# 1843                             GyA
# 7649  CHRISTIAN HUMBERTO LILLO ARAYA
# 9280                  DONDE DON RAUL

# %%
df_directos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13571 entries, 0 to 13570
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   EMAIL         13568 non-null  object
#  1   WHMCS         13571 non-null  float64
#  2   WORKSPACE     13571 non-null  float64
#  3   RUT           13571 non-null  object
#  4   Plan Tuu      13571 non-null  object
#  5   ORGANIZACION  13571 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 636.3+ KB

# %% [markdown]
# ----

# %% [markdown]
# # Archivo **Servicios Haulmer**

# %%
df_sshaulmer = pd.read_excel("/content/drive/MyDrive/Proyecto Innovación 1/Metodología/Datos/Servicios Haulmer (churn).xlsx")

# %%
df_sshaulmer.columns
# Out:
# Index(['Usuario', 'Servicio', 'Partner', 'Empresa', 'Categoria', 'Producto',
#        'Monto Servicio', 'Registro', 'Periodo Registro', 'PeriodoTérmino',
#        'Estado', 'Pagadas', 'Sin Pagar'],
#       dtype='object')

# %%
print("Cantidad de registros : ",df_sshaulmer.shape[0])
print("Cantidad de atributos : ",df_sshaulmer.shape[1])
# Out:
# Cantidad de registros :  22129
# Cantidad de atributos :  13

# %% [markdown]
# ## Análisis exploratorio y preprocesamiento **Servicios Haulmer**

# %%
df_sshaulmer.sample(3)
# Out:
#        Usuario  Servicio Partner  Empresa Categoria Producto  Monto Servicio  \
# 13497  29522.0   64392.0     NaN  Haulmer    Simple   Simple        120000.0
# 19266  41553.0   93588.0     NaN  Haulmer       Tuu      Tuu             0.0
# 15219  32025.0   71151.0     NaN  Haulmer    Simple   Simple         60000.0
#
#         Registro Periodo Registro       PeriodoTérmino  Estado  Pagadas  \
# 13497 2021-02-25       2021-02-01  2023-02-01 00:00:00  Active      3.0
# 19266 2022-01-07       2022-01-01  2022-07-01 00:00:00  Active      7.0
# 15219 2021-04-01       2021-04-01  2023-03-01 00:00:00  Active      3.0
#
#        Sin Pagar
# 13497        0.0
# 19266        0.0
# 15219        0.0

# %%
df_sshaulmer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22129 entries, 0 to 22128
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Usuario           22129 non-null  float64
#  1   Servicio          22129 non-null  float64
#  2   Partner           7 non-null      object
#  3   Empresa           22129 non-null  object
#  4   Categoria         22129 non-null  object
#  5   Producto          22129 non-null  object
#  6   Monto Servicio    22129 non-null  float64
#  7   Registro          22129 non-null  datetime64[ns]
#  8   Periodo Registro  22129 non-null  datetime64[ns]
#  9   PeriodoTérmino    22129 non-null  object
#  10  Estado            22129 non-null  object
#  11  Pagadas           22129 non-null  float64
#  12  Sin Pagar         22129 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# ----
