# %% [markdown]
# ---

# %% [markdown]
# # Análisis de datos archivo Encuesta contratación Haulmer
#
# Por : Christian Vergara Retamal - Benjamín Sánchez Aliste
#
#
# El siguiente archivo fué proporcionado por x perteneciente al equipo/área de x en Haulmer. Los datos dispuestos se obtienen desde el proceso de x con los clientes, en el cuál se detallan las siguientes variables :
#
# *   ID issue :
# *   Ejecutivo que realizó la Venta :
# *   Ejecutivo que realizó la encuesta :
# *   Mail del cliente :
# *   Producto Contratado :
# *   ¿En qué Empresa contrataste tu servicio Hosting? :
# *   ¿Cómo conociste la empresa de hosting? :
# *   ¿Por qué contrataste tu servicio hosting con nosotros?:
# *   ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas) :
# *   ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)? :
# *   ¿Qué otro motivo te llevó a concretar la compra con nosotros?:
# *   Indícanos tu nivel de satisfacción general con el proceso de compra del servicio :
# *   Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas? :
# *   ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?:
# *   ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas? :
# *   El ejecutivo demostró amabilidad y buena disposición para responder mis consultas. :
# *   El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas. :
# *   El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc) :
# *   Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc) :
# *   La navegación en el sitio web es rápida e intuitiva. :
# *   La información respecto al producto (características, precio, etc) es clara y detallada. :
# *   El sitio web me da confianza. :
# *   ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando? :
# *   ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando? :
# *   ¿Tuviste algún problema en la activación de tu servicio? :
# *   Describe el problema que tuviste con la activación de tu servicio :
# *   ¿El problema fue solucionado? :
# *   Indícanos un número de teléfono para poder comunicarnos contigo :
# *   ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido? :
# *   Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación. :
# *   Indícanos el mail o teléfono de quien te gustaría recomendarle nuestro servicio :
# *   email :
# *   clienteid :
# *   Submit Date (UTC) :
# *   Network ID :

# %% [markdown]
# ---

# %% [markdown]
# ## Aspectos Computacionales
#
# **Librerías utilizadas para el funcionamiento del notebook**
#
# * numpy  versión 1.21.6 : Álgebra lineal y matemáticas
# * pandas versión 1.3.5 : Manejo y análisis de estructuras de datos
# * seaborn versión 0.11.2 : Visualización de gráficos
# * matplotlib 3.2.2 : Gráficos
# * Scikit-learn 1.0.2 : Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ## Preparación Ambiente de Trabajo

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importación y observación del set de datos

# %%
# Datos de ConversionLeads Haulmer
data = pd.read_csv("/content/drive/MyDrive/Datos/Datos Tesis/encuestacontratacionbruto.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Las columnas del set de datos
data.columns
# Out:
# Index(['#', 'ID issue', 'Ejecutivo que realizó la Venta',
#        'Ejecutivo que realizó la encuesta', 'Mail del cliente',
#        'Producto Contratado',
#        '¿En qué Empresa contrataste tu servicio Hosting?',
#        '¿Cómo conociste la empresa de hosting?',
#        '¿Por qué contrataste tu servicio hosting con nosotros?',
#        '¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)',
#        '¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?',
#        '¿Qué otro motivo te llevó a concretar la compra con nosotros?',
#        'Indícanos tu nivel de satisfacción general con el proceso de compra del servicio',
#        'Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?',
#        '¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?',
#        '¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?',
# ...

# %%
# Muestra del conjunto de datos
data.sample(5)
# Out:
#                                      # ID issue  \
# 1874  gslsq37kn2u85f8zw0zfwgslsq3ehxu4   PV-162
# 963   98xnaiv9ueyca8wir5k1898xnai04ack  PV-1615
# 2091  2m7lku1tfpzesd2m7loa6h67rs3s3fiy      751
# 574   j3rr9o6oorx2mscem7cj3rr95wtq7o59  PV-2192
# 1001  w4ywpepip2qq0lvb8ysgw4ywp01w7ilj  PV-1545
#
#      Ejecutivo que realizó la Venta Ejecutivo que realizó la encuesta  \
# 1874               Rodrigo González                        Anis Rojas
# 963                    Fabián Pérez                        Anis Rojas
# 2091              Nicolás Ceresuela                               NaN
# 574                   Sin Ejecutivo                     Leandra Reyes
# 1001                  Sin Ejecutivo                        Anis Rojas
#
#                              Mail del cliente Producto Contratado  \
# 1874              panaderiapoolltda@gmail.com  Simpleboleta + POS
# 963             gutierrez.nathali.m@gmail.com                 Tuu
# ...

# %%
# Cantidad de filas y columnas
print("El dataframe anime consta de {} atributos (columnas) y {} registros (filas)".format(data.shape[1], data.shape[0]))
# Out:
# El dataframe anime consta de 37 atributos (columnas) y 2490 registros (filas)

# %% [markdown]
# ## Análisis descriptivo

# %%
# Cantidad de registros por columna y tipo de dato
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2490 entries, 0 to 2489
# Data columns (total 37 columns):
#  #   Column                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                            --------------  -----
#  0   #                                                                                                                                                 2490 non-null   object
#  1   ID issue                                                                                                                                          2490 non-null   object
#  2   Ejecutivo que realizó la Venta                                                                                                                    2489 non-null   object
# ...

# %%
# Descripción de los datos numéricos
data.describe()
# Out:
#        Indícanos tu nivel de satisfacción general con el proceso de compra del servicio  \
# count                                        2489.000000
# mean                                            4.567698
# std                                             0.907463
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?  \
# count                                        1258.000000
# mean                                            4.633545
# std                                             0.787767
# min                                             1.000000
# 25%                                             5.000000
# ...

# %%
# Descripción de los datos categóricos
data.describe(include = "object")
# Out:
#                                        # ID issue  \
# count                               2490     2490
# unique                              2490     2408
# top     bkmvcfiu3xami09kzbkmvczlws2htfp1        2
# freq                                   1        5
#
#        Ejecutivo que realizó la Venta Ejecutivo que realizó la encuesta  \
# count                            2489                              2019
# unique                             22                                 4
# top                     Sin Ejecutivo                        Anis Rojas
# freq                             1274                              1553
#
#           Mail del cliente Producto Contratado  \
# count                 2490                2490
# unique                2413                   6
# top     juan0acu@gmail.com                 Tuu
# freq                     5                 860
#
#        ¿En qué Empresa contrataste tu servicio Hosting?  \
# ...

# %%
# Verificación de datos nulos por columna
data.isna().sum()
# Out:
# #                                                                                                                                                      0
# ID issue                                                                                                                                               0
# Ejecutivo que realizó la Venta                                                                                                                         1
# Ejecutivo que realizó la encuesta                                                                                                                    471
# Mail del cliente                                                                                                                                       0
# Producto Contratado                                                                                                                                    0
# ...

# %% [markdown]
# ## Análisis Univariado de atributos

# %% [markdown]
# ### Variables numéricas

# %%
# Obtención de columnas numéricas del set de datos
columnas_numericas = data.select_dtypes(include = ["float64", "int64"])

# %%
plt.figure(figsize=(20,26))
for index, col in enumerate(columnas_numericas):
    plt.subplot((len(list(columnas_numericas)))+1,1, index+1)
    titulo = str(f"Histograma de la variable '{col}'")
    texto_ejex = str(f"Valores de la variable '{col}'")
    
    if data[col].dtypes == "float64":
        sns.distplot(data[col])
        plt.axvline(data[col].mean(), color='tomato')
        plt.axvline(data[col].median(), color='blue')
        plt.title(titulo, weight='bold')
        plt.xlabel(texto_ejex)
        
    elif data[col].dtypes == "int64":
        sns.distplot(data[col], kde = False, bins = 50)
        plt.axvline(data[col].mean(), color='tomato')
        plt.axvline(data[col].median(), color='blue')
        plt.title(titulo, weight='bold')
        plt.xlabel(texto_ejex)
    plt.tight_layout()

# %% [markdown]
# ### Variables categóricas

# %%
# Creación de función para visualizar frecuencia de valores que puede tomar el respectivo atributo
def plot_freq(df, col): 
  plt.figure(figsize=(10,8))
  aux_dict = df[col].value_counts().to_dict()
  y = list(aux_dict.values())
  plt.barh(*zip(*aux_dict.items()))
  for index, value in enumerate(y):
    plt.text(value, index, str(value))
  plt.title("Frecuencia de la columnas {}".format(col))
  plt.show()
  plt.tight_layout()

# %% [markdown]
# #### Atributo "Ejecutivo que realizó la Venta"

# %%
plot_freq(data, "Ejecutivo que realizó la Venta")

# %% [markdown]
# #### Atributo "Ejecutivo que realizó la encuesta"

# %%
plot_freq(data, "Ejecutivo que realizó la encuesta")

# %% [markdown]
# #### Atributo "Producto Contratado"

# %%
plot_freq(data, "Producto Contratado")

# %% [markdown]
# #### Pregunta de encuesta "¿En qué Empresa contrataste tu servicio Hosting?"

# %%
 plot_freq(data, "¿En qué Empresa contrataste tu servicio Hosting?")

# %% [markdown]
# #### Pregunta de encuesta "¿Cómo conociste la empresa de hosting?"

# %%
 plot_freq(data, "¿Cómo conociste la empresa de hosting?")

# %% [markdown]
# #### Pregunta de encuesta "¿Por qué contrataste tu servicio hosting con nosotros?"

# %%
 plot_freq(data, "¿Por qué contrataste tu servicio hosting con nosotros?")

# %% [markdown]
# #### Pregunta de encuesta "¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas) "

# %%
 plot_freq(data, "¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)")

# %% [markdown]
# #### Pregunta de encuesta "¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?"

# %%
 plot_freq(data, "¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?")

# %% [markdown]
# #### Pregunta de encuesta "Indícanos tu nivel de satisfacción general con el proceso de compra del servicio"

# %%
 plot_freq(data, "Indícanos tu nivel de satisfacción general con el proceso de compra del servicio")

# %% [markdown]
# #### Pregunta de encuesta "Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?"

# %%
 plot_freq(data, "Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?")

# %% [markdown]
# #### Pregunta de encuesta "¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?"

# %%
 plot_freq(data, "¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?")

# %% [markdown]
# #### Pregunta de encuesta "¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?"

# %%
 plot_freq(data, "¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?")

# %% [markdown]
# #### Pregunta de encuesta "El ejecutivo demostró amabilidad y buena disposición para responder mis consultas."

# %%
 plot_freq(data, "El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.")

# %% [markdown]
# #### Pregunta de encuesta "El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas."

# %%
 plot_freq(data, "El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.")

# %% [markdown]
# #### Pregunta de encuesta "El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc)"

# %%
 plot_freq(data, "El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc)")

# %% [markdown]
# #### Pregunta de encuesta "La navegación en el sitio web es rápida e intuitiva."

# %%
 plot_freq(data, "La navegación en el sitio web es rápida e intuitiva.")

# %% [markdown]
# #### Pregunta de encuesta "La información respecto al producto (características, precio, etc) es clara y detallada."

# %%
 plot_freq(data, "La información respecto al producto (características, precio, etc) es clara y detallada.")

# %% [markdown]
# #### Pregunta de encuesta "El sitio web me da confianza."

# %%
 plot_freq(data, "El sitio web me da confianza.")

# %% [markdown]
# #### Pregunta de encuesta "¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando? "

# %%
 plot_freq(data, "¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?")

# %% [markdown]
# #### Pregunta de encuesta "¿Tuviste algún problema en la activación de tu servicio?"

# %%
 plot_freq(data, "¿Tuviste algún problema en la activación de tu servicio?")

# %% [markdown]
# #### Pregunta de encuesta "¿El problema fue solucionado? "

# %%
 plot_freq(data, "¿El problema fue solucionado?")

# %% [markdown]
# #### Pregunta de encuesta "¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?"

# %%
 plot_freq(data, "¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?")
