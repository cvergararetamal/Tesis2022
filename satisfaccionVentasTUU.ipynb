# %% [markdown]
# ---

# %% [markdown]
# # Análisis de datos archivo satisfaccionVentasTUU
#
# 1.   Elemento de lista
# 2.   Elemento de lista
#
#
# Por : Christian Vergara Retamal - Benjamín Sánchez Aliste
#
#
# El siguiente archivo fué proporcionado por x perteneciente al equipo/área de x en Haulmer. Los datos dispuestos se obtienen desde el proceso de x con los clientes, en el cuál se detallan las siguientes variables :
#
# *    Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?:
# *    Mail del cliente:
# *    ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas):
# *    ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?:
# *    ¿Qué otro motivo te llevó a concretar la compra con nosotros?:
# *    Indícanos tu nivel de satisfacción general con el proceso de compra del servicio:
# *    ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?:
# *    ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?:
# *    El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.:
# *    El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.:
# *    El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc):
# *    Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc):
# *    La navegación en el sitio web es rápida e intuitiva.:
# *    La información respecto al producto (características, precio, etc) es clara y detallada.:
# *    El sitio web me da confianza.:
# *    ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?:
# *    ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?:
# *    ¿Tuviste algún problema en la activación de tu servicio?:
# *    Describe el problema que tuviste con la activación de tu servicio:
# *    ¿El problema fue solucionado?:
# *    Indícanos un número de teléfono para poder comunicarnos contigo:
# *    ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?:
# *    Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.:

# %% [markdown]
# ---

# %% [markdown]
# ## Aspectos Computacionales
#
# **Librerías utilizadas para el funcionamiento del notebook**
#
# * numpy  versión 1.21.6 : Álgebra lineal y matemáticas
# * pandas versión 1.3.5 : Manejo y análisis de estructuras de datos
# * seaborn versión 0.11.2 : Visualización de gráficos
# * matplotlib 3.2.2 : Gráficos
# * Scikit-learn 1.0.2 : Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ## Preparación Ambiente de Trabajo

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importación y observación del set de datos

# %%
# Datos de Encuesta satisfaccionVentasTUU
data = pd.read_csv("/content/drive/MyDrive/Datos/Datos Tesis/satisfaccionVentasTUU.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Las columnas del set de datos
data.columns
columnas= data.columns
for i in range(len(columnas)):
  print("*   ",columnas[i]+":")
# Out:
# *    Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?:
# *    Mail del cliente:
# *    ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas):
# *    ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?:
# *    ¿Qué otro motivo te llevó a concretar la compra con nosotros?:
# *    Indícanos tu nivel de satisfacción general con el proceso de compra del servicio:
# *    ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?:
# *    ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?:
# *    El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.:
# *    El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.:
# *    El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc):
# *    Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc):
# *    La navegación en el sitio web es rápida e intuitiva.:
# *    La información respecto al producto (características, precio, etc) es clara y detallada.:
# *    El sitio web me da confianza.:
# *    ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?:
# *    ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?:
# *    ¿Tuviste algún problema en la activación de tu servicio?:
# *    Describe el problema que tuviste con la activación de tu servicio:
# *    ¿El problema fue solucionado?:
# *    Indícanos un número de teléfono para poder comunicarnos contigo:
# *    ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?:
# *    Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.:

# %%
# Muestra del conjunto de datos
data.sample(5)
# Out:
#     Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?  \
# 346                                              Enero
# 9                                                   No
# 301                                                NaN
# 214                                                 No
# 159                                                 Si
#
#                   Mail del cliente  \
# 346                         98,94%
# 9                contacto@cahoe.cl
# 301                            NaN
# 214  carlosgastonparis@hotmail.com
# 159    eduardoanibal1992@gmail.com
#
#     ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)  \
# 346                                             96,81%
# 9                                                Otro.
# 301                                                NaN
# 214              Recomendación de un amigo o conocido.
# 159              Recomendación de un amigo o conocido.
#
#     ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?  \
# 346                                             96,81%
# 9                                                Otros
# 301                                                NaN
# 214                                              Otros
# 159                                  Precio - Calidad.
#
#     ¿Qué otro motivo te llevó a concretar la compra con nosotros?  \
# 346                                             96,81%
# 9                       Vio la máquina pos en un lugar
# 301                                                NaN
# 214                                        Es practico
# 159                                                NaN
#
#     Indícanos tu nivel de satisfacción general con el proceso de compra del servicio  \
# 346                                                NaN
# 9                                                    5
# 301                                                NaN
# 214                                                  4
# 159                                                  5
#
#     ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?  \
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159    Solicitud de Llamado por Formulario de Contacto
#
#      ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?  \
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159                                                5.0
#
#      El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.  \
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159                                                5.0
#
#      El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.  \
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159                                                5.0
#
#      ...  \
# 346  ...
# 9    ...
# 301  ...
# 214  ...
# 159  ...
#
#      La información respecto al producto (características, precio, etc) es clara y detallada.  \
# 346                                                NaN
# 9                                                  5.0
# 301                                                NaN
# 214                                                5.0
# 159                                                NaN
#
#     El sitio web me da confianza.  \
# 346                           NaN
# 9                             5.0
# 301                           NaN
# 214                           5.0
# 159                           NaN
#
#      ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?  \
# 346                                                NaN
# 9                                                  3.0
# 301                                                NaN
# 214                                                5.0
# 159                                                3.0
#
#      ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?  \
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159                                                NaN
#
#      ¿Tuviste algún problema en la activación de tu servicio?  \
# 346                                                NaN
# 9                                                  1.0
# 301                                                NaN
# 214                                                0.0
# 159                                                1.0
#
#      Describe el problema que tuviste con la activación de tu servicio  \
# 346                                                NaN
# 9                             esta a la espera del SII
# 301                                                NaN
# 214                                                NaN
# 159  No puede entrar al espacio de trabajado, no ti...
#
#     ¿El problema fue solucionado?  \
# 346                           NaN
# 9                             0.0
# 301                           NaN
# 214                           NaN
# 159                           0.0
#
#      Indícanos un número de teléfono para poder comunicarnos contigo  \
# 346                                                NaN
# 9                                          56931220626
# 301                                                NaN
# 214                                                NaN
# 159                                        56966248563
#
#     ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?  \
# 346                                                NaN
# 9                                                  7.0
# 301                                                NaN
# 214                                               10.0
# 159                                                7.0
#
#      Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.
# 346                                                NaN
# 9                                                  NaN
# 301                                                NaN
# 214                                                NaN
# 159  Los horarios del meet deberían ser hasta más t...
#
# [5 rows x 23 columns]

# %%
# Cantidad de filas y columnas
print("El dataframe anime consta de {} atributos (columnas) y {} registros (filas)".format(data.shape[1], data.shape[0]))
# Out:
# El dataframe anime consta de 23 atributos (columnas) y 388 registros (filas)

# %% [markdown]
# ## Análisis descriptivo

# %%
# Cantidad de registros por columna y tipo de dato
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 23 columns):
#  #   Column                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                            --------------  -----
#  0   Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?                                                                       310 non-null    object
#  1   Mail del cliente                                                                                                                                  352 non-null    object
#  2   ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)                                                 326 non-null    object
#  3   ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?                                                                     321 non-null    object
#  4   ¿Qué otro motivo te llevó a concretar la compra con nosotros?                                                                                     152 non-null    object
#  5   Indícanos tu nivel de satisfacción general con el proceso de compra del servicio                                                                  262 non-null    object
#  6   ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?                                                                      166 non-null    object
#  7   ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?                                                                             161 non-null    float64
#  8   El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.                                                                159 non-null    float64
#  9   El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.                            159 non-null    float64
#  10  El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc)                          159 non-null    float64
#  11  Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc)  8 non-null      object
#  12  La navegación en el sitio web es rápida e intuitiva.                                                                                              102 non-null    float64
#  13  La información respecto al producto (características, precio, etc) es clara y detallada.                                                          102 non-null    float64
#  14  El sitio web me da confianza.                                                                                                                     102 non-null    float64
#  15  ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?                                   247 non-null    float64
#  16  ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?                                                                      12 non-null     object
#  17  ¿Tuviste algún problema en la activación de tu servicio?                                                                                          247 non-null    float64
#  18  Describe el problema que tuviste con la activación de tu servicio                                                                                 186 non-null    object
#  19  ¿El problema fue solucionado?                                                                                                                     187 non-null    float64
#  20  Indícanos un número de teléfono para poder comunicarnos contigo                                                                                   135 non-null    object
#  21  ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?                                                                          247 non-null    float64
#  22  Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.                                   92 non-null     object
# dtypes: float64(11), object(12)
# memory usage: 69.8+ KB

# %%
# Descripción de los datos numéricos
data.describe()
# Out:
#        ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?  \
# count                                         161.000000
# mean                                            7.739130
# std                                            27.605824
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                           253.000000
#
#        El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.  \
# count                                         159.000000
# mean                                            4.654088
# std                                             0.826671
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.  \
# count                                         159.000000
# mean                                            4.597484
# std                                             0.872357
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc)  \
# count                                         159.000000
# mean                                            4.566038
# std                                             0.875318
# min                                             1.000000
# 25%                                             4.500000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        La navegación en el sitio web es rápida e intuitiva.  \
# count                                         102.000000
# mean                                            4.539216
# std                                             1.001697
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        La información respecto al producto (características, precio, etc) es clara y detallada.  \
# count                                         102.000000
# mean                                            4.568627
# std                                             1.009949
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        El sitio web me da confianza.  \
# count                     102.000000
# mean                        4.627451
# std                         0.921918
# min                         1.000000
# 25%                         5.000000
# 50%                         5.000000
# 75%                         5.000000
# max                         5.000000
#
#        ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?  \
# count                                         247.000000
# mean                                            4.441296
# std                                             0.985461
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        ¿Tuviste algún problema en la activación de tu servicio?  \
# count                                         247.000000
# mean                                            0.757085
# std                                             0.429715
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        ¿El problema fue solucionado?  \
# count                     187.000000
# mean                        0.278075
# std                         0.449253
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         1.000000
# max                         1.000000
#
#        ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?
# count                                         247.000000
# mean                                            7.878543
# std                                             2.461373
# min                                             1.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                            10.000000
# max                                            10.000000

# %%
# Descripción de los datos categóricos
data.describe(include = "object")
# Out:
#        Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?  \
# count                                                 310
# unique                                                 39
# top                                                    Si
# freq                                                  159
#
#        Mail del cliente  \
# count               352
# unique              329
# top               Enero
# freq                  7
#
#        ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)  \
# count                                                 326
# unique                                                 66
# top     Búsqueda del producto /servicio que necesitaba...
# freq                                                   92
#
#        ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?  \
# count                                                 321
# unique                                                 60
# top                                                 Otros
# freq                                                  131
#
#        ¿Qué otro motivo te llevó a concretar la compra con nosotros?  \
# count                                                 152
# unique                                                136
# top                                  Por la recomendación
# freq                                                    6
#
#        Indícanos tu nivel de satisfacción general con el proceso de compra del servicio  \
# count                                                 262
# unique                                                 12
# top                                                     5
# freq                                                  184
#
#        ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?  \
# count                                                 166
# unique                                                 12
# top                  Llamada a nuestra central telefónica
# freq                                                  129
#
#        Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc)  \
# count                                                   8
# unique                                                  8
# top     No le entregó ninguna información de cómo acti...
# freq                                                    1
#
#        ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?  \
# count                                                  12
# unique                                                 12
# top        no ha podido ocuparlo porque no lo ha activado
# freq                                                    1
#
#        Describe el problema que tuviste con la activación de tu servicio  \
# count                                                 186
# unique                                                162
# top      No ha podido realizar la activación del servicio
# freq                                                    8
#
#        Indícanos un número de teléfono para poder comunicarnos contigo  \
# count                                                 135
# unique                                                135
# top                            josefariasllanca@gmail.com
# freq                                                    1
#
#        Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.
# count                                                  92
# unique                                                 87
# top                                             Todo bien
# freq                                                    6

# %%
# Verificación de datos nulos por columna
data.isna().sum()
# Out:
# Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?                                                                          78
# Mail del cliente                                                                                                                                     36
# ¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)                                                    62
# ¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?                                                                        67
# ¿Qué otro motivo te llevó a concretar la compra con nosotros?                                                                                       236
# Indícanos tu nivel de satisfacción general con el proceso de compra del servicio                                                                    126
# ¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?                                                                        222
# ¿Qué tan fácil dirías que fue comunicarse con el ejecutivo de ventas?                                                                               227
# El ejecutivo demostró amabilidad y buena disposición para responder mis consultas.                                                                  229
# El ejecutivo tenía un correcto manejo de información sobre el producto y fue capaz de responder a todas mis consultas.                              229
# El ejecutivo cumplió con los compromisos realizados. (Envío de información complementaria, llamadas calendarizadas, etc)                            229
# Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc)    380
# La navegación en el sitio web es rápida e intuitiva.                                                                                                286
# La información respecto al producto (características, precio, etc) es clara y detallada.                                                            286
# El sitio web me da confianza.                                                                                                                       286
# ¿En qué grado dirías que el producto/servicio que contrataste se ajusta a lo que inicialmente estabas buscando?                                     141
# ¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?                                                                        376
# ¿Tuviste algún problema en la activación de tu servicio?                                                                                            141
# Describe el problema que tuviste con la activación de tu servicio                                                                                   202
# ¿El problema fue solucionado?                                                                                                                       201
# Indícanos un número de teléfono para poder comunicarnos contigo                                                                                     253
# ¿Cuál es la probabilidad que nos recomiendes con algún amigo o conocido?                                                                            141
# Si tienes algún comentario o sugerencia que quieras compartir con nosotros, por favor escríbelo a continuación.                                     296
# dtype: int64

# %% [markdown]
# ## Análisis Univariado de atributos

# %% [markdown]
# ### Variables numéricas

# %%
# Obtención de columnas numéricas del set de datos
columnas_numericas = data.select_dtypes(include = ["float64", "int64"])

# %%
plt.figure(figsize=(20,26))
for index, col in enumerate(columnas_numericas):
    plt.subplot((len(list(columnas_numericas)))+1,1, index+1)
    titulo = str(f"Histograma de la variable '{col}'")
    texto_ejex = str(f"Valores de la variable '{col}'")
    
    if data[col].dtypes == "float64":
        sns.distplot(data[col])
        plt.axvline(data[col].mean(), color='tomato')
        plt.axvline(data[col].median(), color='blue')
        plt.title(titulo, weight='bold')
        plt.xlabel(texto_ejex)
        
    elif data[col].dtypes == "int64":
        sns.distplot(data[col], kde = False, bins = 50)
        plt.axvline(data[col].mean(), color='tomato')
        plt.axvline(data[col].median(), color='blue')
        plt.title(titulo, weight='bold')
        plt.xlabel(texto_ejex)
    plt.tight_layout()

# %% [markdown]
# ### Variables categóricas

# %%
# Creación de función para visualizar frecuencia de valores que puede tomar el respectivo atributo
def plot_freq(df, col): 
  plt.figure(figsize=(10,8))
  aux_dict = df[col].value_counts().to_dict()
  y = list(aux_dict.values())
  plt.barh(*zip(*aux_dict.items()))
  for index, value in enumerate(y):
    plt.text(value, index, str(value))
  plt.title("Frecuencia de la columnas {}".format(col))
  plt.show()
  plt.tight_layout()

# %% [markdown]
# Pregunta encuesta "Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?"

# %%
plot_freq(data, "Durante tu proceso de compra, ¿Fuiste asesorado por un ejecutivo de ventas?")

# %% [markdown]
# #### Pregunta encuesta "¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)"

# %%
plot_freq(data, "¿Cómo conociste a Haulmer o una de sus marcas asociadas? (SimpleBoleta, OpenFactura, ChileFirmas)")

# %% [markdown]
# #### Pregunta encuesta "¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?"

# %%
plot_freq(data, "¿Qué te llevó a concretar la compra con nosotros (Simpleboleta, Openfactura)?")

# %% [markdown]
# #### Pregunta encuesta "¿Qué otro motivo te llevó a concretar la compra con nosotros?"

# %%
plot_freq(data, "¿Qué otro motivo te llevó a concretar la compra con nosotros?")

# %% [markdown]
# #### Pregunta encuesta "Indícanos tu nivel de satisfacción general con el proceso de compra del servicio"

# %%
plot_freq(data, "Indícanos tu nivel de satisfacción general con el proceso de compra del servicio")

# %% [markdown]
# #### Pregunta encuesta "¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?"

# %%
plot_freq(data, "¿A través de qué medio solicitaste ser atendido por  un ejecutivo de ventas?")

# %% [markdown]
# #### Pregunta encuesta "Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc)"

# %%
plot_freq(data, "Cuáles fueron los compromisos donde el ejecutivo NO cumplió con lo prometido (Envío de información complementaria, llamadas calendarizadas, etc)")

# %% [markdown]
# #### Pregunta encuesta "¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?"

# %%
plot_freq(data, "¿Por qué el producto que contrataste NO se ajusta a lo que estabas buscando?")

# %% [markdown]
# #### Pregunta encuesta "Describe el problema que tuviste con la activación de tu servicio"

# %%
plot_freq(data, "Describe el problema que tuviste con la activación de tu servicio")
